# %%
# !git clone https://github.com/haonguyen1107/yolov5.git
# !git clone https://github.com/ultralytics/yolov5

# %%
# copy folder zip vo yolov5 r giai nen
# copy data.yaml vo data
# copy file weight
# them file classes vo

# %%
cd /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !unzip "/content/data_bienso.zip" -d "/content/yolov5/"

# %%
# /content/gdrive/MyDrive/implant
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))

# %%
# !python train.py --data data/implant.yaml --cfg models/yolov5s.yaml --weights '' --batch-size 32 --epochs 10
# !python train.py --data data/data.yaml --cfg models/yolov5s.yaml --weights models/yolov5s.pt --batch-size 32 --epochs 50

# runs/train/exp/weights/yolov5s.pt

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# sua file implant.yaml
#/content/yolov5/runs/train/exp/weights/last.pt
# !python detect.py --source test.jpeg --weights runs/train/exp6/weights/best.pt --conf 0.25

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp5/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
# !unzip "/content/label.zip" -d "/content/yolov5/"
# !rm -rf '/content/yolov5/data_bienso/labels'
